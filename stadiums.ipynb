# %%
# geoapify for soccer (Football) Olympic Venues 2024

# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

import warnings
warnings.filterwarnings("ignore")

# Import API key
from api_keys import geoapify_key

import pycountry

# %%
locations = {
    "Bordeaux Stadium": (44.8974, -0.5616),
    "La Beaujoire Stadium": (47.2534, -1.5219),
    "St.Etienne Stadium": (45.4605, 4.3894),
    "Parc des Princes": (48.8414, 2.2530),
    "Lyon Stadium": (45.7653, 4.9820),
    "Marseille Stadium": (43.2699, 5.3959),
    "Nice Stadium": (43.7051, 7.1926)
}

# %%
football_df = pd.DataFrame({"Stadium":["Bordeaux Stadium","La Beaujoire Stadium",
                                       "St.Etienne Stadium","Parc des Princes","Lyon Stadium",
                                       "Marseille Stadium","Nice Stadium"],
                                       "Lat":[44.8974,47.2534,45.4605,48.8414,45.7653,43.2699,43.7051],
                                       "Lng":[-0.5616,-1.5219, 4.3894, 2.2530, 4.9820, 5.3959, 7.1926],
                                       "Capacity":[42115,35322,41965,47929,59186,67000,36178]})


football_df
# Out:
#                 Stadium      Lat     Lng  Capacity
# 0      Bordeaux Stadium  44.8974 -0.5616     42115
# 1  La Beaujoire Stadium  47.2534 -1.5219     35322
# 2    St.Etienne Stadium  45.4605  4.3894     41965
# 3      Parc des Princes  48.8414  2.2530     47929
# 4          Lyon Stadium  45.7653  4.9820     59186
# 5     Marseille Stadium  43.2699  5.3959     67000
# 6          Nice Stadium  43.7051  7.1926     36178

# %%
# %%capture --no-display

# Configure the map plot
map_plot = football_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Capacity",
    scale = 0.2,
    color = "Stadium",
    xlabel = "Longitude",
    ylabel = "Latitude",
    legend = True
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Stadium,Capacity)
